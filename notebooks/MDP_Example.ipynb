# %%
from aalpy.SULs import MdpSUL
from aalpy.learning_algs import run_stochastic_Lstar
from aalpy.oracles import UnseenOutputRandomWalkEqOracle
from aalpy.utils import get_faulty_coffee_machine_MDP

# get faulty coffe machine found in Chapter 5 of Martin's Tappler PhD thesis
mdp = get_faulty_coffee_machine_MDP()

# get its input alphabet
input_alphabet = mdp.get_input_alphabet()

# wrap it in the SUL
sul = MdpSUL(mdp)

# %%
# Define the eq. oracle
eq_oracle = UnseenOutputRandomWalkEqOracle(input_alphabet, sul=sul, num_steps=1000, reset_prob=0.11,
                                           reset_after_cex=True)

# start learning with verbose output
learned_mdp = run_stochastic_Lstar(input_alphabet, sul, eq_oracle, n_c=20, n_resample=100, min_rounds=10,
                                   max_rounds=50, print_level=3)
# Out:
# Hypothesis: 1: 3 states.
# -----------------------------------------------------
# Prefixes / E set         |('but',)     |('coin',)
# -----------------------------------------------------
# ('init',)                |{'init': 59} |{'beep': 41}
# -----------------------------------------------------
# ('init', 'coin', 'beep') |{}           |{}
# =====================================================
# -----------------------------------------------------
# ('init', 'but', 'init')  |{}           |{}
# -----------------------------------------------------
# ('init', 'coin', 'beep') |{}           |{}
# -----------------------------------------------------
# Counterexample ('init', 'coin', 'beep')
# Hypothesis: 2: 4 states.
# -----------------------------------------------------------------------------------
# Prefixes / E set                          |('but',)                  |('coin',)
# -----------------------------------------------------------------------------------
# ('init',)                                 |{'init': 114}             |{'beep': 86}
# -----------------------------------------------------------------------------------
# ('init', 'coin', 'beep')                  |{'coffee': 24, 'init': 2} |{'beep': 19}
# -----------------------------------------------------------------------------------
# ('init', 'coin', 'beep', 'but', 'coffee') |{}                        |{}
# ===================================================================================
# -----------------------------------------------------------------------------------
# ('init', 'but', 'init')                   |{'init': 23}              |{'beep': 32}
# -----------------------------------------------------------------------------------
# ('init', 'coin', 'beep')                  |{'coffee': 24, 'init': 2} |{'beep': 19}
# -----------------------------------------------------------------------------------
# ('init', 'coin', 'beep', 'but', 'coffee') |{}                        |{}
# -----------------------------------------------------------------------------------
# ('init', 'coin', 'beep', 'but', 'init')   |{}                        |{}
# -----------------------------------------------------------------------------------
# ('init', 'coin', 'beep', 'coin', 'beep')  |{}                        |{}
# -----------------------------------------------------------------------------------
# Counterexample ('init', 'coin', 'beep')
# Hypothesis: 3: 4 states.
# ----------------------------------------------------------------------------------------------------
# Prefixes / E set                                          |('but',)                  |('coin',)
# ----------------------------------------------------------------------------------------------------
# ('init',)                                                 |{'init': 114}             |{'beep': 186}
# ----------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep')                                  |{'coffee': 67, 'init': 4} |{'beep': 74}
# ----------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep', 'but', 'coffee')                 |{'init': 27}              |{'beep': 16}
# ====================================================================================================
# ----------------------------------------------------------------------------------------------------
# ('init', 'but', 'init')                                   |{'init': 23}              |{'beep': 32}
# ----------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep')                                  |{'coffee': 67, 'init': 4} |{'beep': 74}
# ----------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep', 'but', 'coffee')                 |{'init': 27}              |{'beep': 16}
# ----------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep', 'but', 'init')                   |{'init': 1}               |{'beep': 1}
# ----------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep', 'coin', 'beep')                  |{'coffee': 24, 'init': 5} |{'beep': 26}
# ----------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep', 'but', 'coffee', 'but', 'init')  |{}                        |{}
# ----------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep', 'but', 'coffee', 'coin', 'beep') |{}                        |{}
# ----------------------------------------------------------------------------------------------------
# Counterexample ('init', 'coin', 'beep', 'but', 'coffee')
# Hypothesis: 4: 3 states.
# ------------------------------------------------------------------------------------------------------
# Prefixes / E set                                          |('but',)                    |('coin',)
# ------------------------------------------------------------------------------------------------------
# ('init',)                                                 |{'init': 114}               |{'beep': 286}
# ------------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep')                                  |{'coffee': 152, 'init': 19} |{'beep': 74}
# ------------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep', 'but', 'coffee')                 |{'init': 60}                |{'beep': 68}
# ======================================================================================================
# ------------------------------------------------------------------------------------------------------
# ('init', 'but', 'init')                                   |{'init': 23}                |{'beep': 32}
# ------------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep')                                  |{'coffee': 152, 'init': 19} |{'beep': 74}
# ------------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep', 'but', 'coffee')                 |{'init': 60}                |{'beep': 68}
# ------------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep', 'but', 'init')                   |{'init': 9}                 |{'beep': 8}
# ------------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep', 'coin', 'beep')                  |{'coffee': 24, 'init': 5}   |{'beep': 26}
# ------------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep', 'but', 'coffee', 'but', 'init')  |{'init': 20}                |{'beep': 13}
# ------------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep', 'but', 'coffee', 'coin', 'beep') |{'coffee': 28, 'init': 1}   |{'beep': 23}
# ------------------------------------------------------------------------------------------------------
# Hypothesis: 5: 3 states.
# ------------------------------------------------------------------------------------------------------
# Prefixes / E set                                          |('but',)                    |('coin',)
# ------------------------------------------------------------------------------------------------------
# ('init',)                                                 |{'init': 143}               |{'beep': 414}
# ------------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep')                                  |{'coffee': 250, 'init': 32} |{'beep': 88}
# ------------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep', 'but', 'coffee')                 |{'init': 152}               |{'beep': 73}
# ======================================================================================================
# ------------------------------------------------------------------------------------------------------
# ('init', 'but', 'init')                                   |{'init': 32}                |{'beep': 47}
# ------------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep')                                  |{'coffee': 250, 'init': 32} |{'beep': 88}
# ------------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep', 'but', 'coffee')                 |{'init': 152}               |{'beep': 73}
# ------------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep', 'but', 'init')                   |{'init': 15}                |{'beep': 15}
# ------------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep', 'coin', 'beep')                  |{'coffee': 28, 'init': 5}   |{'beep': 34}
# ------------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep', 'but', 'coffee', 'but', 'init')  |{'init': 21}                |{'beep': 103}
# ------------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep', 'but', 'coffee', 'coin', 'beep') |{'coffee': 30, 'init': 1}   |{'beep': 26}
# ------------------------------------------------------------------------------------------------------
# Unambiguous rows: 100.0%; 10 out of 10
# Hypothesis: 6: 3 states.
# ------------------------------------------------------------------------------------------------------
# Prefixes / E set                                          |('but',)                    |('coin',)
# ------------------------------------------------------------------------------------------------------
# ('init',)                                                 |{'init': 143}               |{'beep': 514}
# ------------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep')                                  |{'coffee': 341, 'init': 41} |{'beep': 88}
# ------------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep', 'but', 'coffee')                 |{'init': 152}               |{'beep': 73}
# ======================================================================================================
# ------------------------------------------------------------------------------------------------------
# ('init', 'but', 'init')                                   |{'init': 32}                |{'beep': 47}
# ------------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep')                                  |{'coffee': 341, 'init': 41} |{'beep': 88}
# ------------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep', 'but', 'coffee')                 |{'init': 152}               |{'beep': 73}
# ------------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep', 'but', 'init')                   |{'init': 21}                |{'beep': 18}
# ------------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep', 'coin', 'beep')                  |{'coffee': 28, 'init': 5}   |{'beep': 34}
# ------------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep', 'but', 'coffee', 'but', 'init')  |{'init': 21}                |{'beep': 103}
# ------------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep', 'but', 'coffee', 'coin', 'beep') |{'coffee': 30, 'init': 1}   |{'beep': 26}
# ------------------------------------------------------------------------------------------------------
# Hypothesis: 7: 3 states.
# ------------------------------------------------------------------------------------------------------
# Prefixes / E set                                          |('but',)                    |('coin',)
# ------------------------------------------------------------------------------------------------------
# ('init',)                                                 |{'init': 143}               |{'beep': 614}
# ------------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep')                                  |{'coffee': 429, 'init': 53} |{'beep': 88}
# ------------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep', 'but', 'coffee')                 |{'init': 152}               |{'beep': 73}
# ======================================================================================================
# ------------------------------------------------------------------------------------------------------
# ('init', 'but', 'init')                                   |{'init': 32}                |{'beep': 47}
# ------------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep')                                  |{'coffee': 429, 'init': 53} |{'beep': 88}
# ------------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep', 'but', 'coffee')                 |{'init': 152}               |{'beep': 73}
# ------------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep', 'but', 'init')                   |{'init': 21}                |{'beep': 30}
# ------------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep', 'coin', 'beep')                  |{'coffee': 28, 'init': 5}   |{'beep': 34}
# ------------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep', 'but', 'coffee', 'but', 'init')  |{'init': 21}                |{'beep': 103}
# ------------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep', 'but', 'coffee', 'coin', 'beep') |{'coffee': 30, 'init': 1}   |{'beep': 26}
# ------------------------------------------------------------------------------------------------------
# Hypothesis: 8: 3 states.
# ------------------------------------------------------------------------------------------------------
# Prefixes / E set                                          |('but',)                    |('coin',)
# ------------------------------------------------------------------------------------------------------
# ('init',)                                                 |{'init': 143}               |{'beep': 614}
# ------------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep')                                  |{'coffee': 429, 'init': 53} |{'beep': 88}
# ------------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep', 'but', 'coffee')                 |{'init': 152}               |{'beep': 73}
# ======================================================================================================
# ------------------------------------------------------------------------------------------------------
# ('init', 'but', 'init')                                   |{'init': 32}                |{'beep': 47}
# ------------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep')                                  |{'coffee': 429, 'init': 53} |{'beep': 88}
# ------------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep', 'but', 'coffee')                 |{'init': 152}               |{'beep': 73}
# ------------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep', 'but', 'init')                   |{'init': 21}                |{'beep': 30}
# ------------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep', 'coin', 'beep')                  |{'coffee': 28, 'init': 5}   |{'beep': 34}
# ------------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep', 'but', 'coffee', 'but', 'init')  |{'init': 21}                |{'beep': 103}
# ------------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep', 'but', 'coffee', 'coin', 'beep') |{'coffee': 30, 'init': 1}   |{'beep': 26}
# ------------------------------------------------------------------------------------------------------
# Hypothesis: 9: 3 states.
# ------------------------------------------------------------------------------------------------------
# Prefixes / E set                                          |('but',)                    |('coin',)
# ------------------------------------------------------------------------------------------------------
# ('init',)                                                 |{'init': 143}               |{'beep': 614}
# ------------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep')                                  |{'coffee': 429, 'init': 53} |{'beep': 88}
# ------------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep', 'but', 'coffee')                 |{'init': 152}               |{'beep': 73}
# ======================================================================================================
# ------------------------------------------------------------------------------------------------------
# ('init', 'but', 'init')                                   |{'init': 32}                |{'beep': 47}
# ------------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep')                                  |{'coffee': 429, 'init': 53} |{'beep': 88}
# ------------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep', 'but', 'coffee')                 |{'init': 152}               |{'beep': 73}
# ------------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep', 'but', 'init')                   |{'init': 21}                |{'beep': 30}
# ------------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep', 'coin', 'beep')                  |{'coffee': 28, 'init': 5}   |{'beep': 34}
# ------------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep', 'but', 'coffee', 'but', 'init')  |{'init': 21}                |{'beep': 103}
# ------------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep', 'but', 'coffee', 'coin', 'beep') |{'coffee': 30, 'init': 1}   |{'beep': 26}
# ------------------------------------------------------------------------------------------------------
# Hypothesis: 10: 3 states.
# ------------------------------------------------------------------------------------------------------
# Prefixes / E set                                          |('but',)                    |('coin',)
# ------------------------------------------------------------------------------------------------------
# ('init',)                                                 |{'init': 143}               |{'beep': 614}
# ------------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep')                                  |{'coffee': 429, 'init': 53} |{'beep': 88}
# ------------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep', 'but', 'coffee')                 |{'init': 152}               |{'beep': 73}
# ======================================================================================================
# ------------------------------------------------------------------------------------------------------
# ('init', 'but', 'init')                                   |{'init': 32}                |{'beep': 47}
# ------------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep')                                  |{'coffee': 429, 'init': 53} |{'beep': 88}
# ------------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep', 'but', 'coffee')                 |{'init': 152}               |{'beep': 73}
# ------------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep', 'but', 'init')                   |{'init': 21}                |{'beep': 30}
# ------------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep', 'coin', 'beep')                  |{'coffee': 28, 'init': 5}   |{'beep': 34}
# ------------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep', 'but', 'coffee', 'but', 'init')  |{'init': 21}                |{'beep': 103}
# ------------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep', 'but', 'coffee', 'coin', 'beep') |{'coffee': 30, 'init': 1}   |{'beep': 26}
# ------------------------------------------------------------------------------------------------------
# Unambiguous rows: 100.0%; 10 out of 10
# -----------------------------------
# Learning Finished.
# Learning Rounds:  10
# Number of states: 3
# Time (in seconds)
#   Total                : 0.07
#   Learning algorithm   : 0.07
#   Conformance checking : 0.0
# Learning Algorithm
#  # Membership Queries  : 700
#  # Steps               : 1794
# Equivalence Query
#  # Membership Queries  : 64
#  # Steps               : 500
# -----------------------------------

# %%
# print the learned MDP
print(learned_mdp)
# Out:
# digraph learnedModel {
# s0 [label=init];
# s1 [label=beep];
# s2 [label=coffee];
# s0 -> s0  [label="but : 1.0"];
# s0 -> s1  [label="coin : 1.0"];
# s1 -> s2  [label="but : 0.89"];
# s1 -> s0  [label="but : 0.11"];
# s1 -> s1  [label="coin : 1.0"];
# s2 -> s0  [label="but : 1.0"];
# s2 -> s1  [label="coin : 1.0"];
# __start0 [label="", shape=none];
# __start0 -> s0  [label=""];
# }
