# %%
from aalpy.SULs import MdpSUL
from aalpy.learning_algs import run_stochastic_Lstar
from aalpy.oracles import UnseenOutputRandomWalkEqOracle
from aalpy.utils import get_faulty_coffee_machine_MDP

# get faulty coffe machine found in Chapter 5 of Martin's Tappler PhD thesis
mdp = get_faulty_coffee_machine_MDP()

# get its input alphabet
input_alphabet = mdp.get_input_alphabet()

# wrap it in the SUL
sul = MdpSUL(mdp)

# %%
# Define the eq. oracle
eq_oracle = UnseenOutputRandomWalkEqOracle(input_alphabet, sul=sul, num_steps=1000, reset_prob=0.11,
                                           reset_after_cex=True)

# start learning with verbose output
learned_mdp = run_stochastic_Lstar(input_alphabet, sul, eq_oracle, n_c=20, n_resample=100, min_rounds=10,
                                   max_rounds=50, print_level=3)
# Out:
# -----------------------------------------------------
# Prefixes / E set         |('but',)     |('coin',)
# -----------------------------------------------------
# ('init',)                |{'init': 44} |{'beep': 56}
# -----------------------------------------------------
# ('init', 'coin', 'beep') |{}           |{}
# =====================================================
# -----------------------------------------------------
# ('init', 'but', 'init')  |{}           |{}
# -----------------------------------------------------
# ('init', 'coin', 'beep') |{}           |{}
# -----------------------------------------------------
# Hypothesis: 1: 3 states.
# ------------------------------------------------------------------------------------
# Prefixes / E set                          |('but',)                  |('coin',)
# ------------------------------------------------------------------------------------
# ('init',)                                 |{'init': 94}              |{'beep': 106}
# ------------------------------------------------------------------------------------
# ('init', 'coin', 'beep')                  |{'coffee': 24, 'init': 1} |{'beep': 25}
# ------------------------------------------------------------------------------------
# ('init', 'coin', 'beep', 'but', 'coffee') |{}                        |{}
# ====================================================================================
# ------------------------------------------------------------------------------------
# ('init', 'but', 'init')                   |{'init': 19}              |{'beep': 31}
# ------------------------------------------------------------------------------------
# ('init', 'coin', 'beep')                  |{'coffee': 24, 'init': 1} |{'beep': 25}
# ------------------------------------------------------------------------------------
# ('init', 'coin', 'beep', 'but', 'coffee') |{}                        |{}
# ------------------------------------------------------------------------------------
# ('init', 'coin', 'beep', 'but', 'init')   |{}                        |{}
# ------------------------------------------------------------------------------------
# ('init', 'coin', 'beep', 'coin', 'beep')  |{}                        |{}
# ------------------------------------------------------------------------------------
# Hypothesis: 2: 4 states.
# ----------------------------------------------------------------------------------------------------
# Prefixes / E set                                          |('but',)                  |('coin',)
# ----------------------------------------------------------------------------------------------------
# ('init',)                                                 |{'init': 140}             |{'beep': 160}
# ----------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep')                                  |{'coffee': 42, 'init': 4} |{'beep': 58}
# ----------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep', 'but', 'coffee')                 |{'init': 12}              |{'beep': 6}
# ====================================================================================================
# ----------------------------------------------------------------------------------------------------
# ('init', 'but', 'init')                                   |{'init': 65}              |{'beep': 31}
# ----------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep')                                  |{'coffee': 42, 'init': 4} |{'beep': 58}
# ----------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep', 'but', 'coffee')                 |{'init': 12}              |{'beep': 6}
# ----------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep', 'but', 'init')                   |{'init': 1}               |{'beep': 2}
# ----------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep', 'coin', 'beep')                  |{'init': 3, 'coffee': 12} |{'beep': 18}
# ----------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep', 'but', 'coffee', 'but', 'init')  |{}                        |{}
# ----------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep', 'but', 'coffee', 'coin', 'beep') |{}                        |{}
# ----------------------------------------------------------------------------------------------------
# Hypothesis: 3: 4 states.
# ----------------------------------------------------------------------------------------------------
# Prefixes / E set                                          |('but',)                  |('coin',)
# ----------------------------------------------------------------------------------------------------
# ('init',)                                                 |{'init': 140}             |{'beep': 260}
# ----------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep')                                  |{'coffee': 90, 'init': 8} |{'beep': 106}
# ----------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep', 'but', 'coffee')                 |{'init': 42}              |{'beep': 24}
# ====================================================================================================
# ----------------------------------------------------------------------------------------------------
# ('init', 'but', 'init')                                   |{'init': 65}              |{'beep': 31}
# ----------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep')                                  |{'coffee': 90, 'init': 8} |{'beep': 106}
# ----------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep', 'but', 'coffee')                 |{'init': 42}              |{'beep': 24}
# ----------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep', 'but', 'init')                   |{'init': 3}               |{'beep': 4}
# ----------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep', 'coin', 'beep')                  |{'init': 5, 'coffee': 33} |{'beep': 43}
# ----------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep', 'but', 'coffee', 'but', 'init')  |{'init': 15}              |{'beep': 15}
# ----------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep', 'but', 'coffee', 'coin', 'beep') |{'coffee': 10}            |{'beep': 8}
# ----------------------------------------------------------------------------------------------------
# Hypothesis: 4: 3 states.
# ------------------------------------------------------------------------------------------------------
# Prefixes / E set                                          |('but',)                    |('coin',)
# ------------------------------------------------------------------------------------------------------
# ('init',)                                                 |{'init': 169}               |{'beep': 392}
# ------------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep')                                  |{'coffee': 188, 'init': 23} |{'beep': 121}
# ------------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep', 'but', 'coffee')                 |{'init': 79}                |{'beep': 84}
# ======================================================================================================
# ------------------------------------------------------------------------------------------------------
# ('init', 'but', 'init')                                   |{'init': 79}                |{'beep': 43}
# ------------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep')                                  |{'coffee': 188, 'init': 23} |{'beep': 121}
# ------------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep', 'but', 'coffee')                 |{'init': 79}                |{'beep': 84}
# ------------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep', 'but', 'init')                   |{'init': 12}                |{'beep': 10}
# ------------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep', 'coin', 'beep')                  |{'init': 6, 'coffee': 41}   |{'beep': 46}
# ------------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep', 'but', 'coffee', 'but', 'init')  |{'init': 31}                |{'beep': 35}
# ------------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep', 'but', 'coffee', 'coin', 'beep') |{'coffee': 42, 'init': 5}   |{'beep': 31}
# ------------------------------------------------------------------------------------------------------
# Hypothesis: 5: 3 states.
# Unambiguous rows: 100.0%; 10 out of 10
# ------------------------------------------------------------------------------------------------------
# Prefixes / E set                                          |('but',)                    |('coin',)
# ------------------------------------------------------------------------------------------------------
# ('init',)                                                 |{'init': 169}               |{'beep': 492}
# ------------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep')                                  |{'coffee': 274, 'init': 37} |{'beep': 121}
# ------------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep', 'but', 'coffee')                 |{'init': 79}                |{'beep': 84}
# ======================================================================================================
# ------------------------------------------------------------------------------------------------------
# ('init', 'but', 'init')                                   |{'init': 79}                |{'beep': 43}
# ------------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep')                                  |{'coffee': 274, 'init': 37} |{'beep': 121}
# ------------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep', 'but', 'coffee')                 |{'init': 79}                |{'beep': 84}
# ------------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep', 'but', 'init')                   |{'init': 18}                |{'beep': 18}
# ------------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep', 'coin', 'beep')                  |{'init': 6, 'coffee': 41}   |{'beep': 46}
# ------------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep', 'but', 'coffee', 'but', 'init')  |{'init': 31}                |{'beep': 35}
# ------------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep', 'but', 'coffee', 'coin', 'beep') |{'coffee': 42, 'init': 5}   |{'beep': 31}
# ------------------------------------------------------------------------------------------------------
# Hypothesis: 6: 3 states.
# ------------------------------------------------------------------------------------------------------
# Prefixes / E set                                          |('but',)                    |('coin',)
# ------------------------------------------------------------------------------------------------------
# ('init',)                                                 |{'init': 169}               |{'beep': 592}
# ------------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep')                                  |{'coffee': 361, 'init': 50} |{'beep': 121}
# ------------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep', 'but', 'coffee')                 |{'init': 79}                |{'beep': 84}
# ======================================================================================================
# ------------------------------------------------------------------------------------------------------
# ('init', 'but', 'init')                                   |{'init': 79}                |{'beep': 43}
# ------------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep')                                  |{'coffee': 361, 'init': 50} |{'beep': 121}
# ------------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep', 'but', 'coffee')                 |{'init': 79}                |{'beep': 84}
# ------------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep', 'but', 'init')                   |{'init': 24}                |{'beep': 25}
# ------------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep', 'coin', 'beep')                  |{'init': 6, 'coffee': 41}   |{'beep': 46}
# ------------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep', 'but', 'coffee', 'but', 'init')  |{'init': 31}                |{'beep': 35}
# ------------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep', 'but', 'coffee', 'coin', 'beep') |{'coffee': 42, 'init': 5}   |{'beep': 31}
# ------------------------------------------------------------------------------------------------------
# Hypothesis: 7: 3 states.
# ------------------------------------------------------------------------------------------------------
# Prefixes / E set                                          |('but',)                    |('coin',)
# ------------------------------------------------------------------------------------------------------
# ('init',)                                                 |{'init': 169}               |{'beep': 592}
# ------------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep')                                  |{'coffee': 361, 'init': 50} |{'beep': 121}
# ------------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep', 'but', 'coffee')                 |{'init': 79}                |{'beep': 84}
# ======================================================================================================
# ------------------------------------------------------------------------------------------------------
# ('init', 'but', 'init')                                   |{'init': 79}                |{'beep': 43}
# ------------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep')                                  |{'coffee': 361, 'init': 50} |{'beep': 121}
# ------------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep', 'but', 'coffee')                 |{'init': 79}                |{'beep': 84}
# ------------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep', 'but', 'init')                   |{'init': 24}                |{'beep': 25}
# ------------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep', 'coin', 'beep')                  |{'init': 6, 'coffee': 41}   |{'beep': 46}
# ------------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep', 'but', 'coffee', 'but', 'init')  |{'init': 31}                |{'beep': 35}
# ------------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep', 'but', 'coffee', 'coin', 'beep') |{'coffee': 42, 'init': 5}   |{'beep': 31}
# ------------------------------------------------------------------------------------------------------
# Hypothesis: 8: 3 states.
# ------------------------------------------------------------------------------------------------------
# Prefixes / E set                                          |('but',)                    |('coin',)
# ------------------------------------------------------------------------------------------------------
# ('init',)                                                 |{'init': 169}               |{'beep': 592}
# ------------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep')                                  |{'coffee': 361, 'init': 50} |{'beep': 121}
# ------------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep', 'but', 'coffee')                 |{'init': 79}                |{'beep': 84}
# ======================================================================================================
# ------------------------------------------------------------------------------------------------------
# ('init', 'but', 'init')                                   |{'init': 79}                |{'beep': 43}
# ------------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep')                                  |{'coffee': 361, 'init': 50} |{'beep': 121}
# ------------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep', 'but', 'coffee')                 |{'init': 79}                |{'beep': 84}
# ------------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep', 'but', 'init')                   |{'init': 24}                |{'beep': 25}
# ------------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep', 'coin', 'beep')                  |{'init': 6, 'coffee': 41}   |{'beep': 46}
# ------------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep', 'but', 'coffee', 'but', 'init')  |{'init': 31}                |{'beep': 35}
# ------------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep', 'but', 'coffee', 'coin', 'beep') |{'coffee': 42, 'init': 5}   |{'beep': 31}
# ------------------------------------------------------------------------------------------------------
# Hypothesis: 9: 3 states.
# ------------------------------------------------------------------------------------------------------
# Prefixes / E set                                          |('but',)                    |('coin',)
# ------------------------------------------------------------------------------------------------------
# ('init',)                                                 |{'init': 169}               |{'beep': 592}
# ------------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep')                                  |{'coffee': 361, 'init': 50} |{'beep': 121}
# ------------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep', 'but', 'coffee')                 |{'init': 79}                |{'beep': 84}
# ======================================================================================================
# ------------------------------------------------------------------------------------------------------
# ('init', 'but', 'init')                                   |{'init': 79}                |{'beep': 43}
# ------------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep')                                  |{'coffee': 361, 'init': 50} |{'beep': 121}
# ------------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep', 'but', 'coffee')                 |{'init': 79}                |{'beep': 84}
# ------------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep', 'but', 'init')                   |{'init': 24}                |{'beep': 25}
# ------------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep', 'coin', 'beep')                  |{'init': 6, 'coffee': 41}   |{'beep': 46}
# ------------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep', 'but', 'coffee', 'but', 'init')  |{'init': 31}                |{'beep': 35}
# ------------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep', 'but', 'coffee', 'coin', 'beep') |{'coffee': 42, 'init': 5}   |{'beep': 31}
# ------------------------------------------------------------------------------------------------------
# Hypothesis: 10: 3 states.
# Unambiguous rows: 100.0%; 10 out of 10
# -----------------------------------
# Learning Finished.
# Learning Rounds:  10
# Number of states: 3
# Time (in seconds)
#   Total                : 0.07
#   Learning algorithm   : 0.07
#   Conformance checking : 0.0
# Learning Algorithm
#  # Membership Queries  : 700
#  # Steps               : 1717
# Equivalence Query
#  # Membership Queries  : 68
#  # Steps               : 500
# -----------------------------------

# %%
# print the learned MDP
print(learned_mdp)
# Out:
# digraph path {
# s0 [label=init];
# s1 [label=beep];
# s2 [label=coffee];
# s0 -> s0  [label="but : 1.0"];
# s0 -> s1  [label="coin : 1.0"];
# s1 -> s2  [label="but : 0.88"];
# s1 -> s0  [label="but : 0.12"];
# s1 -> s1  [label="coin : 1.0"];
# s2 -> s0  [label="but : 1.0"];
# s2 -> s1  [label="coin : 1.0"];
# __start0 [label="", shape=none];
# __start0 -> s0  [label=""];
# }
