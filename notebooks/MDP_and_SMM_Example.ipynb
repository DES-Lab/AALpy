# %%
from aalpy.SULs import MdpSUL
from aalpy.learning_algs import run_stochastic_Lstar
from aalpy.oracles import UnseenOutputRandomWalkEqOracle
from aalpy.utils import get_faulty_coffee_machine_MDP

# get faulty coffe machine found in Chapter 5 of Martin's Tappler PhD thesis
mdp = get_faulty_coffee_machine_MDP()

# get its input alphabet
input_alphabet = mdp.get_input_alphabet()

# wrap it in the SUL
sul = MdpSUL(mdp)

# %%
# Define the eq. oracle
eq_oracle = UnseenOutputRandomWalkEqOracle(input_alphabet, sul=sul, num_steps=1000, reset_prob=0.11,
                                           reset_after_cex=True)

# start learning with verbose output
learned_mdp = run_stochastic_Lstar(input_alphabet, sul, eq_oracle, n_c=20, n_resample=200, strategy='classic', min_rounds=10,
                                   max_rounds=50, print_level=3)
# Out:
# Hypothesis: 1: 3 states.
# ------------------------------------------------------
# Prefixes / E set         |('but',)      |('coin',)
# ------------------------------------------------------
# ('init',)                |{'init': 106} |{'beep': 94}
# ------------------------------------------------------
# ('init', 'coin', 'beep') |{}            |{}
# ======================================================
# ------------------------------------------------------
# ('init', 'but', 'init')  |{}            |{}
# ------------------------------------------------------
# Hypothesis: 2: 4 states.
# ------------------------------------------------------------------------------------
# Prefixes / E set                          |('but',)                  |('coin',)
# ------------------------------------------------------------------------------------
# ('init',)                                 |{'init': 210}             |{'beep': 190}
# ------------------------------------------------------------------------------------
# ('init', 'coin', 'beep')                  |{'coffee': 37, 'init': 3} |{'beep': 56}
# ------------------------------------------------------------------------------------
# ('init', 'coin', 'beep', 'but', 'coffee') |{}                        |{}
# ====================================================================================
# ------------------------------------------------------------------------------------
# ('init', 'but', 'init')                   |{'init': 60}              |{'beep': 44}
# ------------------------------------------------------------------------------------
# ('init', 'coin', 'beep', 'but', 'init')   |{}                        |{}
# ------------------------------------------------------------------------------------
# ('init', 'coin', 'beep', 'coin', 'beep')  |{}                        |{}
# ------------------------------------------------------------------------------------
# Hypothesis: 3: 3 states.
# ------------------------------------------------------------------------------------------------------
# Prefixes / E set                                          |('but',)                    |('coin',)
# ------------------------------------------------------------------------------------------------------
# ('init',)                                                 |{'init': 210}               |{'beep': 390}
# ------------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep')                                  |{'coffee': 118, 'init': 15} |{'beep': 163}
# ------------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep', 'but', 'coffee')                 |{'init': 40}                |{'beep': 41}
# ======================================================================================================
# ------------------------------------------------------------------------------------------------------
# ('init', 'but', 'init')                                   |{'init': 60}                |{'beep': 44}
# ------------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep', 'but', 'init')                   |{'init': 8}                 |{'beep': 4}
# ------------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep', 'coin', 'beep')                  |{'coffee': 46, 'init': 6}   |{'beep': 55}
# ------------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep', 'but', 'coffee', 'but', 'init')  |{}                          |{}
# ------------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep', 'but', 'coffee', 'coin', 'beep') |{}                          |{}
# ------------------------------------------------------------------------------------------------------
# Hypothesis: 4: 3 states.
# ------------------------------------------------------------------------------------------------------
# Prefixes / E set                                          |('but',)                    |('coin',)
# ------------------------------------------------------------------------------------------------------
# ('init',)                                                 |{'init': 262}               |{'beep': 646}
# ------------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep')                                  |{'coffee': 322, 'init': 39} |{'beep': 184}
# ------------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep', 'but', 'coffee')                 |{'init': 136}               |{'beep': 146}
# ======================================================================================================
# ------------------------------------------------------------------------------------------------------
# ('init', 'but', 'init')                                   |{'init': 82}                |{'beep': 72}
# ------------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep', 'but', 'init')                   |{'init': 18}                |{'beep': 18}
# ------------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep', 'coin', 'beep')                  |{'coffee': 54, 'init': 6}   |{'beep': 65}
# ------------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep', 'but', 'coffee', 'but', 'init')  |{'init': 61}                |{'beep': 34}
# ------------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep', 'but', 'coffee', 'coin', 'beep') |{'coffee': 34, 'init': 3}   |{'beep': 65}
# ------------------------------------------------------------------------------------------------------
# Counterexample ('init', 'coin', 'beep', 'but', 'init', 'coin', 'beep', 'but')
# Hypothesis: 5: 3 states.
# ------------------------------------------------------------------------------------------------------
# Prefixes / E set                                          |('but',)                    |('coin',)
# ------------------------------------------------------------------------------------------------------
# ('init',)                                                 |{'init': 262}               |{'beep': 846}
# ------------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep')                                  |{'coffee': 510, 'init': 51} |{'beep': 184}
# ------------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep', 'but', 'coffee')                 |{'init': 136}               |{'beep': 146}
# ======================================================================================================
# ------------------------------------------------------------------------------------------------------
# ('init', 'but', 'init')                                   |{'init': 82}                |{'beep': 72}
# ------------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep', 'but', 'init')                   |{'init': 26}                |{'beep': 22}
# ------------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep', 'coin', 'beep')                  |{'coffee': 54, 'init': 6}   |{'beep': 65}
# ------------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep', 'but', 'coffee', 'but', 'init')  |{'init': 61}                |{'beep': 34}
# ------------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep', 'but', 'coffee', 'coin', 'beep') |{'coffee': 34, 'init': 3}   |{'beep': 65}
# ------------------------------------------------------------------------------------------------------
# Counterexample ('init', 'coin', 'beep', 'but', 'init', 'coin', 'beep', 'but')
# Unambiguous rows: 100.0%; 8 out of 8
# -----------------------------------
# Learning Finished.
# Learning Rounds:  5
# Number of states: 3
# Time (in seconds)
#   Total                : 0.05
#   Learning algorithm   : 0.03
#   Conformance checking : 0.02
# Learning Algorithm
#  # Membership Queries  : 1000
#  # Steps               : 3285
# Equivalence Query
#  # Membership Queries  : 108
#  # Steps               : 1000
# -----------------------------------

# %%
# print the learned MDP
print(learned_mdp)
# Out:
# digraph learnedModel {
# s0 [label=init];
# s1 [label=beep];
# s2 [label=coffee];
# s0 -> s0  [label="but : 1.0"];
# s0 -> s1  [label="coin : 1.0"];
# s1 -> s2  [label="but : 0.91"];
# s1 -> s0  [label="but : 0.09"];
# s1 -> s1  [label="coin : 1.0"];
# s2 -> s0  [label="but : 1.0"];
# s2 -> s1  [label="coin : 1.0"];
# __start0 [label="", shape=none];
# __start0 -> s0  [label=""];
# }

# %%
# let us repeat the procedure, but this time learn Stochastic Mealy Machine

# Define the eq. oracle
eq_oracle = UnseenOutputRandomWalkEqOracle(input_alphabet, sul=sul, num_steps=1000, reset_prob=0.11,
                                           reset_after_cex=True)

# start learning with verbose output
learned_smm = run_stochastic_Lstar(input_alphabet, sul, eq_oracle, automaton_type='smm', strategy='normal', min_rounds=10,
                                   max_rounds=50, print_level=3)
# Out:
# Hypothesis: 1: 1 states.
# -----------------------------------------------
# Prefixes / E set |('but',)      |('coin',)
# -----------------------------------------------
# ()               |{'init': 254} |{'beep': 246}
# ===============================================
# -----------------------------------------------
# ('but', 'init')  |{}            |{}
# -----------------------------------------------
# ('coin', 'beep') |{}            |{}
# -----------------------------------------------
# Counterexample ['but', 'init', 'coin', 'beep', 'coin', 'beep', 'but']
# Hypothesis: 2: 2 states.
# --------------------------------------------------------------------------------------------------------------------------------------
# Prefixes / E set                  |('but',)                    |('coin',)     |('but', 'init', 'coin', 'beep', 'coin', 'beep', 'but')
# --------------------------------------------------------------------------------------------------------------------------------------
# ()                                |{'init': 543}               |{'beep': 458} |{'coffee': 137, 'init': 6}
# --------------------------------------------------------------------------------------------------------------------------------------
# ('coin', 'beep')                  |{'coffee': 128, 'init': 16} |{'beep': 68}  |{'init': 1, 'coffee': 15}
# ======================================================================================================================================
# --------------------------------------------------------------------------------------------------------------------------------------
# ('but', 'init')                   |{'init': 146}               |{'beep': 143} |{'coffee': 125, 'init': 21}
# --------------------------------------------------------------------------------------------------------------------------------------
# ('coin', 'beep', 'but', 'coffee') |{}                          |{}            |{}
# --------------------------------------------------------------------------------------------------------------------------------------
# ('coin', 'beep', 'but', 'init')   |{}                          |{'beep': 16}  |{}
# --------------------------------------------------------------------------------------------------------------------------------------
# ('coin', 'beep', 'coin', 'beep')  |{}                          |{}            |{}
# --------------------------------------------------------------------------------------------------------------------------------------
# Counterexample ('but', 'init', 'coin', 'beep', 'coin', 'beep', 'but')
# Hypothesis: 3: 2 states.
# -------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Prefixes / E set                  |('but',)                    |('coin',)     |('but', 'init', 'coin', 'beep', 'coin', 'beep', 'but') |('coin', 'beep', 'coin', 'beep', 'but')
# -------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ()                                |{'init': 632}               |{'beep': 869} |{'coffee': 188, 'init': 12}                            |{'coffee': 88, 'init': 7}
# -------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ('coin', 'beep')                  |{'coffee': 342, 'init': 43} |{'beep': 238} |{'init': 3, 'coffee': 26}                              |{'coffee': 31, 'init': 1}
# ===============================================================================================================================================================================
# -------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ('but', 'init')                   |{'init': 178}               |{'beep': 200} |{'coffee': 153, 'init': 25}                            |{'coffee': 188, 'init': 12}
# -------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ('coin', 'beep', 'but', 'coffee') |{'init': 102}               |{'beep': 112} |{'coffee': 93, 'init': 9}                              |{'coffee': 100, 'init': 12}
# -------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ('coin', 'beep', 'but', 'init')   |{'init': 14}                |{'beep': 29}  |{'coffee': 14}                                         |{'init': 3, 'coffee': 26}
# -------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ('coin', 'beep', 'coin', 'beep')  |{'coffee': 88, 'init': 7}   |{'beep': 75}  |{'coffee': 7}                                          |{'coffee': 38, 'init': 5}
# -------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Hypothesis: 4: 2 states.
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Prefixes / E set                  |('but',)                    |('coin',)      |('but', 'init', 'coin', 'beep', 'coin', 'beep', 'but') |('coin', 'beep', 'coin', 'beep', 'but')
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ()                                |{'init': 821}               |{'beep': 1288} |{'coffee': 272, 'init': 17}                            |{'coffee': 164, 'init': 17}
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ('coin', 'beep')                  |{'coffee': 555, 'init': 69} |{'beep': 410}  |{'init': 4, 'coffee': 41}                              |{'coffee': 72, 'init': 5}
# ================================================================================================================================================================================
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ('but', 'init')                   |{'init': 256}               |{'beep': 306}  |{'coffee': 204, 'init': 29}                            |{'coffee': 272, 'init': 17}
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ('coin', 'beep', 'but', 'coffee') |{'init': 211}               |{'beep': 213}  |{'coffee': 185, 'init': 18}                            |{'coffee': 189, 'init': 19}
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ('coin', 'beep', 'but', 'init')   |{'init': 23}                |{'beep': 46}   |{'coffee': 20, 'init': 1}                              |{'init': 4, 'coffee': 41}
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ('coin', 'beep', 'coin', 'beep')  |{'coffee': 164, 'init': 17} |{'beep': 160}  |{'coffee': 13, 'init': 1}                              |{'coffee': 71, 'init': 8}
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Hypothesis: 5: 2 states.
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Prefixes / E set                  |('but',)                    |('coin',)      |('but', 'init', 'coin', 'beep', 'coin', 'beep', 'but') |('coin', 'beep', 'coin', 'beep', 'but')
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ()                                |{'init': 941}               |{'beep': 1668} |{'coffee': 330, 'init': 28}                            |{'coffee': 234, 'init': 25}
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ('coin', 'beep')                  |{'coffee': 756, 'init': 96} |{'beep': 562}  |{'init': 4, 'coffee': 52}                              |{'coffee': 103, 'init': 9}
# ================================================================================================================================================================================
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ('but', 'init')                   |{'init': 307}               |{'beep': 375}  |{'coffee': 250, 'init': 34}                            |{'coffee': 330, 'init': 28}
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ('coin', 'beep', 'but', 'coffee') |{'init': 319}               |{'beep': 306}  |{'coffee': 281, 'init': 30}                            |{'coffee': 272, 'init': 29}
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ('coin', 'beep', 'but', 'init')   |{'init': 39}                |{'beep': 57}   |{'coffee': 35, 'init': 2}                              |{'init': 4, 'coffee': 52}
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ('coin', 'beep', 'coin', 'beep')  |{'coffee': 234, 'init': 25} |{'beep': 234}  |{'coffee': 20, 'init': 2}                              |{'coffee': 106, 'init': 12}
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Unambiguous rows: 100.0%; 6 out of 6
# Hypothesis: 6: 2 states.
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Prefixes / E set                  |('but',)                     |('coin',)      |('but', 'init', 'coin', 'beep', 'coin', 'beep', 'but') |('coin', 'beep', 'coin', 'beep', 'but')
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ()                                |{'init': 1071}               |{'beep': 2038} |{'coffee': 398, 'init': 36}                            |{'coffee': 298, 'init': 33}
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ('coin', 'beep')                  |{'coffee': 963, 'init': 118} |{'beep': 703}  |{'init': 4, 'coffee': 64}                              |{'coffee': 134, 'init': 11}
# =================================================================================================================================================================================
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ('but', 'init')                   |{'init': 361}                |{'beep': 451}  |{'coffee': 302, 'init': 36}                            |{'coffee': 398, 'init': 36}
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ('coin', 'beep', 'but', 'coffee') |{'init': 422}                |{'beep': 410}  |{'coffee': 371, 'init': 43}                            |{'coffee': 367, 'init': 38}
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ('coin', 'beep', 'but', 'init')   |{'init': 49}                 |{'beep': 69}   |{'coffee': 44, 'init': 3}                              |{'init': 4, 'coffee': 64}
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ('coin', 'beep', 'coin', 'beep')  |{'coffee': 298, 'init': 33}  |{'beep': 303}  |{'coffee': 28, 'init': 2}                              |{'coffee': 140, 'init': 14}
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Hypothesis: 7: 2 states.
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Prefixes / E set                  |('but',)                      |('coin',)      |('but', 'init', 'coin', 'beep', 'coin', 'beep', 'but') |('coin', 'beep', 'coin', 'beep', 'but')
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ()                                |{'init': 1185}                |{'beep': 2424} |{'coffee': 460, 'init': 42}                            |{'coffee': 383, 'init': 41}
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ('coin', 'beep')                  |{'coffee': 1149, 'init': 138} |{'beep': 883}  |{'init': 5, 'coffee': 74}                              |{'coffee': 176, 'init': 14}
# ==================================================================================================================================================================================
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ('but', 'init')                   |{'init': 407}                 |{'beep': 519}  |{'coffee': 344, 'init': 40}                            |{'coffee': 460, 'init': 42}
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ('coin', 'beep', 'but', 'coffee') |{'init': 521}                 |{'beep': 497}  |{'coffee': 454, 'init': 59}                            |{'coffee': 446, 'init': 46}
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ('coin', 'beep', 'but', 'init')   |{'init': 58}                  |{'beep': 80}   |{'coffee': 51, 'init': 5}                              |{'init': 5, 'coffee': 74}
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ('coin', 'beep', 'coin', 'beep')  |{'coffee': 383, 'init': 41}   |{'beep': 390}  |{'coffee': 36, 'init': 2}                              |{'coffee': 178, 'init': 18}
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Hypothesis: 8: 2 states.
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Prefixes / E set                  |('but',)                      |('coin',)      |('but', 'init', 'coin', 'beep', 'coin', 'beep', 'but') |('coin', 'beep', 'coin', 'beep', 'but')
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ()                                |{'init': 1312}                |{'beep': 2797} |{'coffee': 536, 'init': 49}                            |{'coffee': 456, 'init': 47}
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ('coin', 'beep')                  |{'coffee': 1355, 'init': 161} |{'beep': 1027} |{'init': 6, 'coffee': 82}                              |{'coffee': 199, 'init': 18}
# ==================================================================================================================================================================================
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ('but', 'init')                   |{'init': 451}                 |{'beep': 602}  |{'coffee': 384, 'init': 44}                            |{'coffee': 536, 'init': 49}
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ('coin', 'beep', 'but', 'coffee') |{'init': 623}                 |{'beep': 601}  |{'coffee': 550, 'init': 65}                            |{'coffee': 533, 'init': 63}
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ('coin', 'beep', 'but', 'init')   |{'init': 72}                  |{'beep': 89}   |{'coffee': 64, 'init': 6}                              |{'init': 6, 'coffee': 82}
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ('coin', 'beep', 'coin', 'beep')  |{'coffee': 456, 'init': 47}   |{'beep': 455}  |{'coffee': 41, 'init': 3}                              |{'coffee': 214, 'init': 20}
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Hypothesis: 9: 2 states.
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Prefixes / E set                  |('but',)                      |('coin',)      |('but', 'init', 'coin', 'beep', 'coin', 'beep', 'but') |('coin', 'beep', 'coin', 'beep', 'but')
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ()                                |{'init': 1445}                |{'beep': 3164} |{'coffee': 613, 'init': 55}                            |{'coffee': 517, 'init': 54}
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ('coin', 'beep')                  |{'coffee': 1576, 'init': 172} |{'beep': 1162} |{'init': 7, 'coffee': 86}                              |{'coffee': 228, 'init': 23}
# ==================================================================================================================================================================================
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ('but', 'init')                   |{'init': 501}                 |{'beep': 685}  |{'coffee': 429, 'init': 49}                            |{'coffee': 613, 'init': 55}
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ('coin', 'beep', 'but', 'coffee') |{'init': 731}                 |{'beep': 714}  |{'coffee': 649, 'init': 74}                            |{'coffee': 629, 'init': 80}
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ('coin', 'beep', 'but', 'init')   |{'init': 78}                  |{'beep': 94}   |{'coffee': 70, 'init': 6}                              |{'init': 7, 'coffee': 86}
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ('coin', 'beep', 'coin', 'beep')  |{'coffee': 517, 'init': 54}   |{'beep': 522}  |{'coffee': 48, 'init': 3}                              |{'coffee': 244, 'init': 23}
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Hypothesis: 10: 2 states.
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Prefixes / E set                  |('but',)                      |('coin',)      |('but', 'init', 'coin', 'beep', 'coin', 'beep', 'but') |('coin', 'beep', 'coin', 'beep', 'but')
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ()                                |{'init': 1581}                |{'beep': 3528} |{'coffee': 691, 'init': 68}                            |{'coffee': 581, 'init': 56}
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ('coin', 'beep')                  |{'coffee': 1773, 'init': 194} |{'beep': 1307} |{'init': 7, 'coffee': 97}                              |{'coffee': 265, 'init': 26}
# ==================================================================================================================================================================================
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ('but', 'init')                   |{'init': 546}                 |{'beep': 776}  |{'coffee': 466, 'init': 57}                            |{'coffee': 691, 'init': 68}
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ('coin', 'beep', 'but', 'coffee') |{'init': 835}                 |{'beep': 807}  |{'coffee': 742, 'init': 85}                            |{'coffee': 709, 'init': 93}
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ('coin', 'beep', 'but', 'init')   |{'init': 89}                  |{'beep': 105}  |{'coffee': 80, 'init': 7}                              |{'init': 7, 'coffee': 97}
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ('coin', 'beep', 'coin', 'beep')  |{'coffee': 581, 'init': 56}   |{'beep': 601}  |{'coffee': 50, 'init': 3}                              |{'coffee': 276, 'init': 30}
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Unambiguous rows: 100.0%; 6 out of 6
# -----------------------------------
# Learning Finished.
# Learning Rounds:  10
# Number of states: 2
# Time (in seconds)
#   Total                : 0.34
#   Learning algorithm   : 0.25
#   Conformance checking : 0.09
# Learning Algorithm
#  # Membership Queries  : 5500
#  # Steps               : 24455
# Equivalence Query
#  # Membership Queries  : 116
#  # Steps               : 1004
# -----------------------------------

# %%
print(learned_smm)
# Out:
# digraph learnedModel {
# s0 [label=s0];
# s1 [label=s1];
# s0 -> s0  [label="but/init:1.0"];
# s0 -> s1  [label="coin/beep:1.0"];
# s1 -> s0  [label="but/coffee:0.9"];
# s1 -> s0  [label="but/init:0.1"];
# s1 -> s1  [label="coin/beep:1.0"];
# __start0 [label="", shape=none];
# __start0 -> s0  [label=""];
# }
