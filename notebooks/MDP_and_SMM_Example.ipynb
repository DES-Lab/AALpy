# %%
from aalpy.SULs import MdpSUL
from aalpy.learning_algs import run_stochastic_Lstar
from aalpy.oracles import RandomWalkEqOracle
from aalpy.utils import get_faulty_coffee_machine_MDP

# get faulty coffe machine found in Chapter 5 of Martin's Tappler PhD thesis
mdp = get_faulty_coffee_machine_MDP()

# get its input alphabet
input_alphabet = mdp.get_input_alphabet()

# wrap it in the SUL
sul = MdpSUL(mdp)

# %%
# Define the eq. oracle
eq_oracle = RandomWalkEqOracle(input_alphabet, sul=sul, num_steps=1000, reset_prob=0.11,
                                           reset_after_cex=True)

# start learning with verbose output
learned_mdp = run_stochastic_Lstar(input_alphabet, sul, eq_oracle, n_c=20, n_resample=500, strategy='classic', min_rounds=10,
                                   max_rounds=50, cex_processing=None, print_level=3)
# Out:
# Hypothesis: 1: 3 states.
# -------------------------------------------------------
# Prefixes / E set         |('but',)      |('coin',)
# -------------------------------------------------------
# ('init',)                |{'init': 256} |{'beep': 244}
# -------------------------------------------------------
# ('init', 'coin', 'beep') |{}            |{}
# =======================================================
# -------------------------------------------------------
# ('init', 'but', 'init')  |{}            |{}
# -------------------------------------------------------
# Hypothesis: 2: 4 states.
# --------------------------------------------------------------------------------------
# Prefixes / E set                          |('but',)                    |('coin',)
# --------------------------------------------------------------------------------------
# ('init',)                                 |{'init': 508}               |{'beep': 492}
# --------------------------------------------------------------------------------------
# ('init', 'coin', 'beep')                  |{'coffee': 107, 'init': 15} |{'beep': 126}
# --------------------------------------------------------------------------------------
# ('init', 'coin', 'beep', 'but', 'coffee') |{}                          |{}
# ======================================================================================
# --------------------------------------------------------------------------------------
# ('init', 'but', 'init')                   |{'init': 122}               |{'beep': 130}
# --------------------------------------------------------------------------------------
# ('init', 'coin', 'beep', 'but', 'init')   |{}                          |{}
# --------------------------------------------------------------------------------------
# ('init', 'coin', 'beep', 'coin', 'beep')  |{}                          |{}
# --------------------------------------------------------------------------------------
# Hypothesis: 3: 3 states.
# ------------------------------------------------------------------------------------------------------
# Prefixes / E set                                          |('but',)                    |('coin',)
# ------------------------------------------------------------------------------------------------------
# ('init',)                                                 |{'init': 508}               |{'beep': 992}
# ------------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep')                                  |{'coffee': 336, 'init': 40} |{'beep': 372}
# ------------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep', 'but', 'coffee')                 |{'init': 118}               |{'beep': 111}
# ======================================================================================================
# ------------------------------------------------------------------------------------------------------
# ('init', 'but', 'init')                                   |{'init': 122}               |{'beep': 130}
# ------------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep', 'but', 'init')                   |{'init': 14}                |{'beep': 11}
# ------------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep', 'coin', 'beep')                  |{'coffee': 131, 'init': 7}  |{'beep': 108}
# ------------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep', 'but', 'coffee', 'but', 'init')  |{}                          |{}
# ------------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep', 'but', 'coffee', 'coin', 'beep') |{}                          |{}
# ------------------------------------------------------------------------------------------------------
# Hypothesis: 4: 3 states.
# -------------------------------------------------------------------------------------------------------
# Prefixes / E set                                          |('but',)                    |('coin',)
# -------------------------------------------------------------------------------------------------------
# ('init',)                                                 |{'init': 562}               |{'beep': 1549}
# -------------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep')                                  |{'coffee': 813, 'init': 88} |{'beep': 399}
# -------------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep', 'but', 'coffee')                 |{'init': 368}               |{'beep': 334}
# =======================================================================================================
# -------------------------------------------------------------------------------------------------------
# ('init', 'but', 'init')                                   |{'init': 142}               |{'beep': 158}
# -------------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep', 'but', 'init')                   |{'init': 39}                |{'beep': 34}
# -------------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep', 'coin', 'beep')                  |{'coffee': 140, 'init': 9}  |{'beep': 121}
# -------------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep', 'but', 'coffee', 'but', 'init')  |{'init': 122}               |{'beep': 128}
# -------------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep', 'but', 'coffee', 'coin', 'beep') |{'coffee': 106, 'init': 10} |{'beep': 106}
# -------------------------------------------------------------------------------------------------------
# Counterexample ('init', 'but', 'init', 'coin', 'beep', 'but')
# Hypothesis: 5: 3 states.
# -------------------------------------------------------------------------------------------------------
# Prefixes / E set                                          |('but',)                    |('coin',)
# -------------------------------------------------------------------------------------------------------
# ('init',)                                                 |{'init': 1062}              |{'beep': 1549}
# -------------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep')                                  |{'coffee': 813, 'init': 88} |{'beep': 399}
# -------------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep', 'but', 'coffee')                 |{'init': 368}               |{'beep': 334}
# =======================================================================================================
# -------------------------------------------------------------------------------------------------------
# ('init', 'but', 'init')                                   |{'init': 369}               |{'beep': 431}
# -------------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep', 'but', 'init')                   |{'init': 39}                |{'beep': 34}
# -------------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep', 'coin', 'beep')                  |{'coffee': 140, 'init': 9}  |{'beep': 121}
# -------------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep', 'but', 'coffee', 'but', 'init')  |{'init': 122}               |{'beep': 128}
# -------------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep', 'but', 'coffee', 'coin', 'beep') |{'coffee': 106, 'init': 10} |{'beep': 106}
# -------------------------------------------------------------------------------------------------------
# Counterexample ('init', 'coin', 'beep', 'but', 'init', 'coin', 'beep', 'but')
# Unambiguous rows: 100.0%; 12 out of 12
# Hypothesis: 6: 3 states.
# ---------------------------------------------------------------------------------------------------------
# Prefixes / E set                                          |('but',)                      |('coin',)
# ---------------------------------------------------------------------------------------------------------
# ('init',)                                                 |{'init': 1062}                |{'beep': 2049}
# ---------------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep')                                  |{'coffee': 1255, 'init': 146} |{'beep': 399}
# ---------------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep', 'but', 'coffee')                 |{'init': 368}                 |{'beep': 334}
# =========================================================================================================
# ---------------------------------------------------------------------------------------------------------
# ('init', 'but', 'init')                                   |{'init': 369}                 |{'beep': 431}
# ---------------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep', 'but', 'init')                   |{'init': 67}                  |{'beep': 64}
# ---------------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep', 'coin', 'beep')                  |{'coffee': 140, 'init': 9}    |{'beep': 121}
# ---------------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep', 'but', 'coffee', 'but', 'init')  |{'init': 122}                 |{'beep': 128}
# ---------------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep', 'but', 'coffee', 'coin', 'beep') |{'coffee': 106, 'init': 10}   |{'beep': 106}
# ---------------------------------------------------------------------------------------------------------
# Counterexample ('init', 'coin', 'beep', 'but', 'init', 'coin', 'beep', 'but')
# Hypothesis: 7: 3 states.
# ---------------------------------------------------------------------------------------------------------
# Prefixes / E set                                          |('but',)                      |('coin',)
# ---------------------------------------------------------------------------------------------------------
# ('init',)                                                 |{'init': 1062}                |{'beep': 2549}
# ---------------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep')                                  |{'coffee': 1705, 'init': 196} |{'beep': 399}
# ---------------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep', 'but', 'coffee')                 |{'init': 368}                 |{'beep': 334}
# =========================================================================================================
# ---------------------------------------------------------------------------------------------------------
# ('init', 'but', 'init')                                   |{'init': 369}                 |{'beep': 431}
# ---------------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep', 'but', 'init')                   |{'init': 89}                  |{'beep': 92}
# ---------------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep', 'coin', 'beep')                  |{'coffee': 140, 'init': 9}    |{'beep': 121}
# ---------------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep', 'but', 'coffee', 'but', 'init')  |{'init': 122}                 |{'beep': 128}
# ---------------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep', 'but', 'coffee', 'coin', 'beep') |{'coffee': 106, 'init': 10}   |{'beep': 106}
# ---------------------------------------------------------------------------------------------------------
# Counterexample ('init', 'coin', 'beep', 'coin', 'beep', 'coin', 'beep', 'coin', 'beep', 'but')
# Hypothesis: 8: 3 states.
# ---------------------------------------------------------------------------------------------------------
# Prefixes / E set                                          |('but',)                      |('coin',)
# ---------------------------------------------------------------------------------------------------------
# ('init',)                                                 |{'init': 1062}                |{'beep': 3049}
# ---------------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep')                                  |{'coffee': 1705, 'init': 196} |{'beep': 899}
# ---------------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep', 'but', 'coffee')                 |{'init': 368}                 |{'beep': 334}
# =========================================================================================================
# ---------------------------------------------------------------------------------------------------------
# ('init', 'but', 'init')                                   |{'init': 369}                 |{'beep': 431}
# ---------------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep', 'but', 'init')                   |{'init': 89}                  |{'beep': 92}
# ---------------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep', 'coin', 'beep')                  |{'coffee': 358, 'init': 27}   |{'beep': 385}
# ---------------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep', 'but', 'coffee', 'but', 'init')  |{'init': 122}                 |{'beep': 128}
# ---------------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep', 'but', 'coffee', 'coin', 'beep') |{'coffee': 106, 'init': 10}   |{'beep': 106}
# ---------------------------------------------------------------------------------------------------------
# Counterexample ('init', 'coin', 'beep', 'but', 'coffee', 'but', 'init', 'coin', 'beep', 'but')
# Hypothesis: 9: 3 states.
# ---------------------------------------------------------------------------------------------------------
# Prefixes / E set                                          |('but',)                      |('coin',)
# ---------------------------------------------------------------------------------------------------------
# ('init',)                                                 |{'init': 1062}                |{'beep': 3549}
# ---------------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep')                                  |{'coffee': 2141, 'init': 260} |{'beep': 899}
# ---------------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep', 'but', 'coffee')                 |{'init': 804}                 |{'beep': 334}
# =========================================================================================================
# ---------------------------------------------------------------------------------------------------------
# ('init', 'but', 'init')                                   |{'init': 369}                 |{'beep': 431}
# ---------------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep', 'but', 'init')                   |{'init': 89}                  |{'beep': 92}
# ---------------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep', 'coin', 'beep')                  |{'coffee': 358, 'init': 27}   |{'beep': 385}
# ---------------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep', 'but', 'coffee', 'but', 'init')  |{'init': 330}                 |{'beep': 356}
# ---------------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep', 'but', 'coffee', 'coin', 'beep') |{'coffee': 106, 'init': 10}   |{'beep': 106}
# ---------------------------------------------------------------------------------------------------------
# Counterexample ('init', 'coin', 'beep', 'but', 'coffee', 'coin', 'beep', 'coin', 'beep', 'but')
# Hypothesis: 10: 3 states.
# ---------------------------------------------------------------------------------------------------------
# Prefixes / E set                                          |('but',)                      |('coin',)
# ---------------------------------------------------------------------------------------------------------
# ('init',)                                                 |{'init': 1062}                |{'beep': 4049}
# ---------------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep')                                  |{'coffee': 2586, 'init': 315} |{'beep': 899}
# ---------------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep', 'but', 'coffee')                 |{'init': 804}                 |{'beep': 779}
# =========================================================================================================
# ---------------------------------------------------------------------------------------------------------
# ('init', 'but', 'init')                                   |{'init': 369}                 |{'beep': 431}
# ---------------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep', 'but', 'init')                   |{'init': 89}                  |{'beep': 92}
# ---------------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep', 'coin', 'beep')                  |{'coffee': 358, 'init': 27}   |{'beep': 385}
# ---------------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep', 'but', 'coffee', 'but', 'init')  |{'init': 330}                 |{'beep': 356}
# ---------------------------------------------------------------------------------------------------------
# ('init', 'coin', 'beep', 'but', 'coffee', 'coin', 'beep') |{'coffee': 300, 'init': 30}   |{'beep': 337}
# ---------------------------------------------------------------------------------------------------------
# Counterexample ('init', 'but', 'init', 'but', 'init', 'but', 'init', 'coin', 'beep', 'but')
# Unambiguous rows: 100.0%; 17 out of 17
# -----------------------------------
# Learning Finished.
# Learning Rounds:  10
# Number of states: 3
# Time (in seconds)
#   Total                : 0.2
#   Learning algorithm   : 0.19
#   Conformance checking : 0.01
# Learning Algorithm
#  # Membership Queries  : 5500
#  # Steps               : 19566
# Equivalence Query
#  # Membership Queries  : 111
#  # Steps               : 1000
# -----------------------------------

# %%
# print the learned MDP
print(learned_mdp)
# Out:
# digraph learnedModel {
# s0 [label=init];
# s1 [label=beep];
# s2 [label=coffee];
# s0 -> s0  [label="but : 1.0"];
# s0 -> s1  [label="coin : 1.0"];
# s1 -> s2  [label="but : 0.89"];
# s1 -> s0  [label="but : 0.11"];
# s1 -> s1  [label="coin : 1.0"];
# s2 -> s0  [label="but : 1.0"];
# s2 -> s1  [label="coin : 1.0"];
# __start0 [label="", shape=none];
# __start0 -> s0  [label=""];
# }

# %%
# let us repeat the procedure, but this time learn Stochastic Mealy Machine

# Define the eq. oracle
eq_oracle = RandomWalkEqOracle(input_alphabet, sul=sul, num_steps=1000, reset_prob=0.11,
                                           reset_after_cex=True)

# start learning with verbose output
learned_smm = run_stochastic_Lstar(input_alphabet, sul, eq_oracle, automaton_type='smm', strategy='normal', min_rounds=10,
                                   max_rounds=50, cex_processing=None, print_level=3)
# Out:
# Hypothesis: 1: 1 states.
# -----------------------------------------------
# Prefixes / E set |('but',)      |('coin',)
# -----------------------------------------------
# ()               |{'init': 266} |{'beep': 234}
# ===============================================
# -----------------------------------------------
# ('but', 'init')  |{}            |{}
# -----------------------------------------------
# ('coin', 'beep') |{}            |{}
# -----------------------------------------------
# Counterexample ['coin', 'beep', 'coin', 'beep', 'coin', 'beep', 'but']
# Hypothesis: 2: 2 states.
# -----------------------------------------------------------------------------
# Prefixes / E set                  |('but',)                   |('coin',)
# -----------------------------------------------------------------------------
# ()                                |{'init': 379}              |{'beep': 622}
# -----------------------------------------------------------------------------
# ('coin', 'beep')                  |{'coffee': 38, 'init': 5}  |{'beep': 345}
# =============================================================================
# -----------------------------------------------------------------------------
# ('but', 'init')                   |{'init': 51}               |{'beep': 62}
# -----------------------------------------------------------------------------
# ('coin', 'beep', 'but', 'coffee') |{}                         |{}
# -----------------------------------------------------------------------------
# ('coin', 'beep', 'but', 'init')   |{}                         |{}
# -----------------------------------------------------------------------------
# ('coin', 'beep', 'coin', 'beep')  |{'coffee': 55, 'init': 14} |{'beep': 276}
# -----------------------------------------------------------------------------
# Hypothesis: 3: 2 states.
# -------------------------------------------------------------------------------
# Prefixes / E set                  |('but',)                    |('coin',)
# -------------------------------------------------------------------------------
# ()                                |{'init': 515}               |{'beep': 1084}
# -------------------------------------------------------------------------------
# ('coin', 'beep')                  |{'coffee': 338, 'init': 36} |{'beep': 469}
# ===============================================================================
# -------------------------------------------------------------------------------
# ('but', 'init')                   |{'init': 116}               |{'beep': 129}
# -------------------------------------------------------------------------------
# ('coin', 'beep', 'but', 'coffee') |{'init': 142}               |{'beep': 156}
# -------------------------------------------------------------------------------
# ('coin', 'beep', 'but', 'init')   |{'init': 17}                |{'beep': 14}
# -------------------------------------------------------------------------------
# ('coin', 'beep', 'coin', 'beep')  |{'coffee': 107, 'init': 19} |{'beep': 340}
# -------------------------------------------------------------------------------
# Hypothesis: 4: 2 states.
# -------------------------------------------------------------------------------
# Prefixes / E set                  |('but',)                    |('coin',)
# -------------------------------------------------------------------------------
# ()                                |{'init': 639}               |{'beep': 1460}
# -------------------------------------------------------------------------------
# ('coin', 'beep')                  |{'coffee': 538, 'init': 61} |{'beep': 620}
# ===============================================================================
# -------------------------------------------------------------------------------
# ('but', 'init')                   |{'init': 177}               |{'beep': 192}
# -------------------------------------------------------------------------------
# ('coin', 'beep', 'but', 'coffee') |{'init': 250}               |{'beep': 248}
# -------------------------------------------------------------------------------
# ('coin', 'beep', 'but', 'init')   |{'init': 31}                |{'beep': 25}
# -------------------------------------------------------------------------------
# ('coin', 'beep', 'coin', 'beep')  |{'coffee': 175, 'init': 24} |{'beep': 418}
# -------------------------------------------------------------------------------
# Hypothesis: 5: 2 states.
# -------------------------------------------------------------------------------
# Prefixes / E set                  |('but',)                    |('coin',)
# -------------------------------------------------------------------------------
# ()                                |{'init': 767}               |{'beep': 1832}
# -------------------------------------------------------------------------------
# ('coin', 'beep')                  |{'coffee': 737, 'init': 92} |{'beep': 762}
# ===============================================================================
# -------------------------------------------------------------------------------
# ('but', 'init')                   |{'init': 242}               |{'beep': 255}
# -------------------------------------------------------------------------------
# ('coin', 'beep', 'but', 'coffee') |{'init': 351}               |{'beep': 346}
# -------------------------------------------------------------------------------
# ('coin', 'beep', 'but', 'init')   |{'init': 45}                |{'beep': 42}
# -------------------------------------------------------------------------------
# ('coin', 'beep', 'coin', 'beep')  |{'coffee': 250, 'init': 33} |{'beep': 476}
# -------------------------------------------------------------------------------
# Unambiguous rows: 100.0%; 6 out of 6
# Hypothesis: 6: 2 states.
# --------------------------------------------------------------------------------
# Prefixes / E set                  |('but',)                     |('coin',)
# --------------------------------------------------------------------------------
# ()                                |{'init': 898}                |{'beep': 2201}
# --------------------------------------------------------------------------------
# ('coin', 'beep')                  |{'coffee': 933, 'init': 117} |{'beep': 910}
# ================================================================================
# --------------------------------------------------------------------------------
# ('but', 'init')                   |{'init': 315}                |{'beep': 313}
# --------------------------------------------------------------------------------
# ('coin', 'beep', 'but', 'coffee') |{'init': 456}                |{'beep': 437}
# --------------------------------------------------------------------------------
# ('coin', 'beep', 'but', 'init')   |{'init': 59}                 |{'beep': 53}
# --------------------------------------------------------------------------------
# ('coin', 'beep', 'coin', 'beep')  |{'coffee': 320, 'init': 44}  |{'beep': 543}
# --------------------------------------------------------------------------------
# Hypothesis: 7: 2 states.
# ---------------------------------------------------------------------------------
# Prefixes / E set                  |('but',)                      |('coin',)
# ---------------------------------------------------------------------------------
# ()                                |{'init': 1015}                |{'beep': 2584}
# ---------------------------------------------------------------------------------
# ('coin', 'beep')                  |{'coffee': 1140, 'init': 144} |{'beep': 1059}
# =================================================================================
# ---------------------------------------------------------------------------------
# ('but', 'init')                   |{'init': 372}                 |{'beep': 373}
# ---------------------------------------------------------------------------------
# ('coin', 'beep', 'but', 'coffee') |{'init': 568}                 |{'beep': 532}
# ---------------------------------------------------------------------------------
# ('coin', 'beep', 'but', 'init')   |{'init': 72}                  |{'beep': 67}
# ---------------------------------------------------------------------------------
# ('coin', 'beep', 'coin', 'beep')  |{'coffee': 384, 'init': 48}   |{'beep': 624}
# ---------------------------------------------------------------------------------
# Hypothesis: 8: 2 states.
# ---------------------------------------------------------------------------------
# Prefixes / E set                  |('but',)                      |('coin',)
# ---------------------------------------------------------------------------------
# ()                                |{'init': 1129}                |{'beep': 2970}
# ---------------------------------------------------------------------------------
# ('coin', 'beep')                  |{'coffee': 1363, 'init': 172} |{'beep': 1194}
# =================================================================================
# ---------------------------------------------------------------------------------
# ('but', 'init')                   |{'init': 433}                 |{'beep': 426}
# ---------------------------------------------------------------------------------
# ('coin', 'beep', 'but', 'coffee') |{'init': 679}                 |{'beep': 644}
# ---------------------------------------------------------------------------------
# ('coin', 'beep', 'but', 'init')   |{'init': 90}                  |{'beep': 77}
# ---------------------------------------------------------------------------------
# ('coin', 'beep', 'coin', 'beep')  |{'coffee': 444, 'init': 56}   |{'beep': 691}
# ---------------------------------------------------------------------------------
# Hypothesis: 9: 2 states.
# ---------------------------------------------------------------------------------
# Prefixes / E set                  |('but',)                      |('coin',)
# ---------------------------------------------------------------------------------
# ()                                |{'init': 1261}                |{'beep': 3338}
# ---------------------------------------------------------------------------------
# ('coin', 'beep')                  |{'coffee': 1578, 'init': 189} |{'beep': 1330}
# =================================================================================
# ---------------------------------------------------------------------------------
# ('but', 'init')                   |{'init': 497}                 |{'beep': 494}
# ---------------------------------------------------------------------------------
# ('coin', 'beep', 'but', 'coffee') |{'init': 781}                 |{'beep': 757}
# ---------------------------------------------------------------------------------
# ('coin', 'beep', 'but', 'init')   |{'init': 93}                  |{'beep': 91}
# ---------------------------------------------------------------------------------
# ('coin', 'beep', 'coin', 'beep')  |{'coffee': 511, 'init': 69}   |{'beep': 747}
# ---------------------------------------------------------------------------------
# Hypothesis: 10: 2 states.
# ---------------------------------------------------------------------------------
# Prefixes / E set                  |('but',)                      |('coin',)
# ---------------------------------------------------------------------------------
# ()                                |{'init': 1379}                |{'beep': 3720}
# ---------------------------------------------------------------------------------
# ('coin', 'beep')                  |{'coffee': 1810, 'init': 210} |{'beep': 1459}
# =================================================================================
# ---------------------------------------------------------------------------------
# ('but', 'init')                   |{'init': 557}                 |{'beep': 552}
# ---------------------------------------------------------------------------------
# ('coin', 'beep', 'but', 'coffee') |{'init': 894}                 |{'beep': 876}
# ---------------------------------------------------------------------------------
# ('coin', 'beep', 'but', 'init')   |{'init': 99}                  |{'beep': 106}
# ---------------------------------------------------------------------------------
# ('coin', 'beep', 'coin', 'beep')  |{'coffee': 565, 'init': 73}   |{'beep': 818}
# ---------------------------------------------------------------------------------
# Unambiguous rows: 100.0%; 6 out of 6
# -----------------------------------
# Learning Finished.
# Learning Rounds:  10
# Number of states: 2
# Time (in seconds)
#   Total                : 0.22
#   Learning algorithm   : 0.11
#   Conformance checking : 0.11
# Learning Algorithm
#  # Membership Queries  : 5500
#  # Steps               : 15611
# Equivalence Query
#  # Membership Queries  : 107
#  # Steps               : 1004
# -----------------------------------

# %%
print(learned_smm)
# Out:
# digraph learnedModel {
# s0 [label=s0];
# s1 [label=s1];
# s0 -> s0  [label="but/init:1.0"];
# s0 -> s1  [label="coin/beep:1.0"];
# s1 -> s0  [label="but/coffee:0.9"];
# s1 -> s0  [label="but/init:0.1"];
# s1 -> s1  [label="coin/beep:1.0"];
# __start0 [label="", shape=none];
# __start0 -> s0  [label=""];
# }
